# %% [markdown]
# # Program that makes intro clips for each item

# %%
import os
from transformers import AutoProcessor, BarkModel
from moviepy.editor import AudioClip, AudioFileClip, concatenate_audioclips
import scipy
import pandas as pd
from tqdm import tqdm

import sys
sys.path.append('../audio_concatenation_v2')
from audio_functions_v2 import *

# %%
os.environ['HUGGINGFACEHUB_API_TOKEN'] = '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'

# %%
# Instantiate model
processor = AutoProcessor.from_pretrained("suno/bark")
model = BarkModel.from_pretrained("suno/bark")

voice_preset = "v2/en_speaker_6"

# %%
df = pd.read_csv("output.csv")
print(df.shape)
df.head()
# Out:
# (193, 10)
#    Unnamed: 0 channel                        episode  \
# 0           0    a16z  Politics & the Future of Tech
# 1           1    a16z  Politics & the Future of Tech
# 2           2    a16z  Politics & the Future of Tech
# 3           3    a16z  Politics & the Future of Tech
# 4           4    a16z  Politics & the Future of Tech
#
#                                              chapter  start_time  end_time  \
# 0                                             Teaser         0.0      38.0
# 1                                              Intro        38.0     149.0
# 2                  Why get involved in politics now?       149.0     701.0
# 3        Big Tech's involvement in political process       701.0    1294.0
# 4  Q: In what ways do you see the relationship be...      1294.0    1567.0
#
#                                                 text  \
# 0  you know ignoring Tech uh is kind of no longer...
# 1  [Music] welcome back everybody uh we are very ...
# 2  of strategy is and how we think about this yea...
# 3  everybody for submitting questions um on X um ...
# 4  progress okay good so let's go to the um next ...
#
#                       file_name_prefix  prev_index  next_index
# 0  Politics & the Future of Tech - 001         NaN         1.0
# 1  Politics & the Future of Tech - 002         0.0         2.0
# 2  Politics & the Future of Tech - 003         1.0         3.0
# 3  Politics & the Future of Tech - 004         2.0         4.0
# 4  Politics & the Future of Tech - 005         3.0         5.0

# %%
df['chapter'].unique()
# Out:
# array(['Teaser', 'Intro', 'Why get involved in politics now?',
#        "Big Tech's involvement in political process",
#        'Q: In what ways do you see the relationship between Silicon Valley and D.C. evolving?',
#        'Where we need regulation',
#        'Determining where politicians stand with tech',
#        'Future regulation and potential for destruction',
#        'Intersection of regulation and technology',
#        'Big Tech and the reality of competition',
#        'Q: What would happen if there was zero regulation of AI?',
#        'Q: How important is the development of decentralized AI and how can the U.S. retain innovation leadership?',
#        'Research universities and lack of AI funding',
#        'Bipolar tech world and U.S. Vs. China',
#        'Q: Are European AI companies becoming less interesting investment targets for U.S. based VC’s due to the regulatory landscape?',
#        'Q: What countries could be receptive to Techno-Optimism?',
#        'Q: Will the lobbying efforts by good-faith American crypto firms will be able to move the needle politically?',
#        'Thoughts on recent TikTok legislation',
#        'Q: How do you find common ground with groups that you can benefit from working with, but are opposed ideologically?',
#        'Q: Would either of you ever consider running for office?',
#        'Sign off', 'The Promise of Advanced Nuclear Reactors',
#        "Nuclear Energy's Current Landscape",
#        'Vulnerabilities in Fuel Delivery', "Nuclear Energy's Timeline",
#        'Portable Microreactors and Mass Production',
#        "Nuclear Energy's Role in America",
#        'Challenges of Portable Micro Reactors',
#        'The Evolution of Nuclear Reactors',
#        'Nuclear’s Public Perception and Safety',
#        'The Global Need for Nuclear Power',
#        'Introduction to scaling laws and their impact',
#        'Arthur Mensch and the Founding of Mistral',
#        'Mistral 7b and the launch of Mixtral',
#        'Misconceptions about open source, the state of open vs. closed models, and future requirements for scaling LLMs',
#        'Open Source in AI: Scaling laws, Industry Impact, data efficiency, and new model architectures',
#        'Safety concerns of open source models.',
#        'Recommendations for policymakers in regulating AI technologies.',
#        'Predictions on how advancements in LLMs will change user interactions with technology',
#        'Potential applications in various fields like gaming and enterprise.',
#        'Call to action for builders, researchers, and developers',
#        'Introduction', 'Limits of LLMs', 'Bilingualism and thinking',
#        'Video prediction',
#        'JEPA (Joint-Embedding Predictive Architecture)', 'JEPA vs LLMs',
#        'DINO and I-JEPA', 'V-JEPA', 'Hierarchical planning',
#        'Autoregressive LLMs', 'AI hallucination', 'Reasoning in AI',
#        'Reinforcement learning', 'Woke AI', 'Open source',
#        'AI and ideology', 'Marc Andreesen', 'Llama 3', 'AGI',
#        'AI doomers', 'Joscha Bach', 'Humanoid robots',
#        'Hope for the future', 'OpenAI board saga', 'Ilya Sutskever',
#        'Elon Musk lawsuit', 'Sora', 'GPT-4', 'Memory & privacy', 'Q',
#        'GPT-5', '7 trillion of compute', 'Google and Gemini',
#        'Leap to GPT-5', 'Aliens', 'Joining OpenAI',
#        'Are scaling and AI safety intertwined?', 'Anthropic Early Days',
#        "Amazon's Investment in Anthropic", 'FTX investment in Anthropic',
#        "Anthropic's Business Today", "Dario's Advice For Builders",
#        'Should we pause AI progress?', 'Future of AI',
#        "Dario's Biggest AI Safety Concerns",
#        'How Anthropic Deals With AI Bias',
#        "Anthropic's Responsible Scaling Policy",
#        'Testifying in front of Congress', 'Will AI destroy humanity?',
#        'GPT3 vs GPT4', 'The memification of a CEO',
#        'What are you most surprised by with AI?',
#        "Why don't you like the term AGI?", '2024 AI Predictions',
#        "Dario's opinion on open-source models",
#        'Probability of AI Catastrophe', 'Misuse of AI',
#        "Looking ahead: Dario's optimistic outlook on AI",
#        'Welcome Emmett Shear', 'Products leading to Twitch',
#        'Justin.tv (before Twitch was Twitch)', 'Growing Twitch',
#        'Winning over streamers', 'Streamers want fame, love and money',
#        'Amazon acquihire', 'Declining value to more money',
#        'Changes in levels of abstraction', 'Management lessons',
#        "Remote work doesn't work", 'Mentors and coaching',
#        'Ambitions of the founder', 'Back to YC', 'AI Concerns',
#        'Being a techno optimist', 'Turning 40',
#        'The Benefits of Being a Generalist', 'Acquiring Domain Expertise',
#        'The Constant Learning Curve in Cybersecurity',
#        'Understanding the Cybersecurity Industry',
#        "Nikesh's 3 Rules For M&A",
#        'The Role of Marketing and Storytelling in Tech',
#        'Leadership and Management in Large Companies',
#        'The Challenge of Scaling and Managing People',
#        'Transitioning Roles and the Importance of Skill Sets',
#        'The Art of Making Successful Career Choices',
#        'The Journey from Analyst to Tech Entrepreneur',
#        'The Impact of Artificial Intelligence in Business',
#        'The Importance of Product Obsession in Tech Leadership',
#        'The Journey from India to the U.S. and the Pursuit of Education',
#        'Venturing into the World of Investment and Venture Capital',
#        'The Mission-Driven Aspect of Cybersecurity',
#        'Romanticizing the Past: A Perspective on Life and Career',
#        'Where are we in the AI race', 'What is the race about',
#        'Biggest challenge with AI', 'When will we see AGI',
#        'New thoughts on regulation', 'Where is China now',
#        'EV conversion speed', 'Chinese competition', 'Chinese cars',
#        'Selfsufficient Mars', 'How many Rockets',
#        'When will we be on Mars', 'New technology', 'Consciousness',
#        'Earth', 'X Twitter', 'Russia', 'Brazil', 'Is Twitter fun',
#        'Is Twitter a geopolitical force',
#        'The key to managing smart people',
#        'How to balance micromanagement and delegate',
#        'Working every waking hour', 'Elon Musk challenge',
#        'How important is speed', 'Why SpaceX has been so successful',
#        'Learning from mistakes', 'Bet the company', 'Accept failure',
#        'PhDs are useless', 'Learning from video games', 'Can you hear me',
#        'Storm has passed', 'Why are you skeptical', 'Legacy', 'Outro',
#        'Whats on your mind',
#        'How can technology be a driver for economic growth',
#        'Microsofts partnership with Open AI',
#        'Where is Microsoft in the AI ecosystem',
#        'Year 2 of the Paradigm Shift', 'Scaling Laws',
#        'Small Language Models', 'Tech in Geopolitics',
#        'Quantum Computing', 'Gaming', 'Changes at Microsoft', 'Empathy',
#        'Lifes experiences', 'Empathy and execution', 'Humility', 'Poetry',
#        'Advice to young people'], dtype=object)

# %%
# Make a clip intro for each clip
for index, row in tqdm(df.iterrows()):
    
    make_clip_intro(row['channel'], row['chapter'], model, processor, voice_preset)
# Out:
# 0it [00:00, ?it/s]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:10000 for open-end generation.
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# 13it [02:53, 13.32s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:10000 for open-end generation.
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# 14it [05:09, 25.48s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:10000 for open-end generation.
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# 15it [07:33, 40.15s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:10000 for open-end generation.
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# 16it [09:35, 52.48s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:10000 for open-end generation.
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# 17it [12:06, 69.96s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:10000 for open-end generation.
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# 18it [14:16, 82.05s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:10000 for open-end generation.
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# 19it [17:07, 101.98s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:10000 for open-end generation.
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# 20it [18:57, 103.97s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:10000 for open-end generation.
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# 21it [21:29, 116.35s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:10000 for open-end generation.
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# 22it [24:32, 134.23s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:10000 for open-end generation.
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# 23it [27:05, 139.33s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:10000 for open-end generation.
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# 24it [29:58, 148.82s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:10000 for open-end generation.
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# 25it [31:30, 132.38s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:10000 for open-end generation.
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# 26it [33:52, 135.21s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:10000 for open-end generation.
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# 27it [35:42, 127.95s/it]The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:10000 for open-end generation.
# 27it [36:56, 82.10s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[29], line 5
#       3 if index < 12:
#       4     continue
# ----> 5 make_clip_intro(row['channel'], row['chapter'], model, processor, voice_preset)
#
# File ~/Documents/HackDartmouth/pod-clip/clip_intro_maker/../audio_concatenation_v2/audio_functions_v2.py:159, in make_clip_intro(podcast, chapter_description, model, processor, voice_preset)
#     156 inputs = processor(text_prompt, voice_preset=voice_preset)
#     158 # Run voice generator
# --> 159 audio_array = model.generate(**inputs)
#     160 audio_array = audio_array.cpu().numpy().squeeze()
#     162 # Create audio clip
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/torch/utils/_contextlib.py:115, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     112 @functools.wraps(func)
#     113 def decorate_context(*args, **kwargs):
#     114     with ctx_factory():
# --> 115         return func(*args, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/transformers/models/bark/modeling_bark.py:1829, in BarkModel.generate(self, input_ids, history_prompt, return_output_lengths, **kwargs)
#    1821 semantic_output = self.semantic.generate(
#    1822     input_ids,
#    1823     history_prompt=history_prompt,
#    1824     semantic_generation_config=semantic_generation_config,
#    1825     **kwargs_semantic,
#    1826 )
#    1828 # 2. Generate from the coarse model
# -> 1829 coarse_output = self.coarse_acoustics.generate(
#    1830     semantic_output,
#    1831     history_prompt=history_prompt,
#    1832     semantic_generation_config=semantic_generation_config,
#    1833     coarse_generation_config=coarse_generation_config,
#    1834     codebook_size=self.generation_config.codebook_size,
#    1835     return_output_lengths=return_output_lengths,
#    1836     **kwargs_coarse,
#    1837 )
#    1839 output_lengths = None
#    1840 if return_output_lengths:
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/transformers/models/bark/modeling_bark.py:1220, in BarkCoarseModel.generate(self, semantic_output, semantic_generation_config, coarse_generation_config, codebook_size, history_prompt, return_output_lengths, **kwargs)
#    1206 input_coarse = torch.hstack(
#    1207     [
#    1208         input_coarse,
#    (...)
#    1211     ]
#    1212 )
#    1214 alternatingLogitsProcessor = AlternatingCodebooksLogitsProcessor(
#    1215     input_coarse.shape[1],
#    1216     semantic_generation_config.semantic_vocab_size,
#    1217     codebook_size,
#    1218 )
# -> 1220 output_coarse = super().generate(
#    1221     input_coarse,
#    1222     logits_processor=[alternatingLogitsProcessor],
#    1223     max_new_tokens=min(sliding_window_len, max_generated_len - total_generated_len),
#    1224     generation_config=coarse_generation_config,
#    1225     **kwargs,
#    1226 )
#    1228 input_coarse_len = input_coarse.shape[1]
#    1230 x_coarse = torch.hstack([x_coarse, output_coarse[:, input_coarse_len:]])
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/torch/utils/_contextlib.py:115, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     112 @functools.wraps(func)
#     113 def decorate_context(*args, **kwargs):
#     114     with ctx_factory():
# --> 115         return func(*args, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/transformers/generation/utils.py:1575, in GenerationMixin.generate(self, inputs, generation_config, logits_processor, stopping_criteria, prefix_allowed_tokens_fn, synced_gpus, assistant_model, streamer, negative_prompt_ids, negative_prompt_attention_mask, **kwargs)
#    1567     input_ids, model_kwargs = self._expand_inputs_for_generation(
#    1568         input_ids=input_ids,
#    1569         expand_size=generation_config.num_return_sequences,
#    1570         is_encoder_decoder=self.config.is_encoder_decoder,
#    1571         **model_kwargs,
#    1572     )
#    1574     # 13. run sample
# -> 1575     result = self._sample(
#    1576         input_ids,
#    1577         logits_processor=prepared_logits_processor,
#    1578         logits_warper=logits_warper,
#    1579         stopping_criteria=prepared_stopping_criteria,
#    1580         pad_token_id=generation_config.pad_token_id,
#    1581         eos_token_id=generation_config.eos_token_id,
#    1582         output_scores=generation_config.output_scores,
#    1583         output_logits=generation_config.output_logits,
#    1584         return_dict_in_generate=generation_config.return_dict_in_generate,
#    1585         synced_gpus=synced_gpus,
#    1586         streamer=streamer,
#    1587         **model_kwargs,
#    1588     )
#    1590 elif generation_mode == GenerationMode.BEAM_SEARCH:
#    1591     # 11. prepare beam search scorer
#    1592     beam_scorer = BeamSearchScorer(
#    1593         batch_size=batch_size,
#    1594         num_beams=generation_config.num_beams,
#    (...)
#    1599         max_length=generation_config.max_length,
#    1600     )
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/transformers/generation/utils.py:2697, in GenerationMixin._sample(self, input_ids, logits_processor, stopping_criteria, logits_warper, max_length, pad_token_id, eos_token_id, output_attentions, output_hidden_states, output_scores, output_logits, return_dict_in_generate, synced_gpus, streamer, **model_kwargs)
#    2694 model_inputs = self.prepare_inputs_for_generation(input_ids, **model_kwargs)
#    2696 # forward pass to get next token
# -> 2697 outputs = self(
#    2698     **model_inputs,
#    2699     return_dict=True,
#    2700     output_attentions=output_attentions,
#    2701     output_hidden_states=output_hidden_states,
#    2702 )
#    2704 if synced_gpus and this_peer_finished:
#    2705     continue  # don't waste resources running the code we don't need
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/transformers/models/bark/modeling_bark.py:851, in BarkCausalModel.forward(self, input_ids, past_key_values, attention_mask, position_ids, head_mask, labels, input_embeds, use_cache, output_attentions, output_hidden_states, return_dict)
#     841     outputs = self._gradient_checkpointing_func(
#     842         block.__call__,
#     843         hidden_states,
#    (...)
#     848         output_attentions,
#     849     )
#     850 else:
# --> 851     outputs = block(
#     852         hidden_states,
#     853         past_key_values=past_layer_key_values,
#     854         attention_mask=attention_mask,
#     855         head_mask=head_mask[i],
#     856         use_cache=use_cache,
#     857         output_attentions=output_attentions,
#     858     )
#     860 hidden_states = outputs[0]
#     862 if use_cache:
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/transformers/models/bark/modeling_bark.py:454, in BarkBlock.forward(self, hidden_states, past_key_values, attention_mask, head_mask, use_cache, output_attentions)
#     443 def forward(
#     444     self,
#     445     hidden_states,
#    (...)
#     450     output_attentions=False,
#     451 ):
#     452     intermediary_hidden_states = self.layernorm_1(hidden_states)
# --> 454     attn_outputs = self.attn(
#     455         intermediary_hidden_states,
#     456         past_key_values=past_key_values,
#     457         attention_mask=attention_mask,
#     458         head_mask=head_mask,
#     459         use_cache=use_cache,
#     460         output_attentions=output_attentions,
#     461     )
#     463     attn_output = attn_outputs[0]  # output_attn: output, present_key_values, (attn_weights)
#     464     outputs = attn_outputs[1:]
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/transformers/models/bark/modeling_bark.py:181, in BarkSelfAttention.forward(self, hidden_states, attention_mask, past_key_values, head_mask, use_cache, output_attentions)
#     171 def forward(
#     172     self,
#     173     hidden_states,
#    (...)
#     179 ):
#     180     # calculate query, key, values for all heads in batch and move head forward to be the batch dim
# --> 181     query, key, value = self.att_proj(hidden_states).split(self.embed_dim, dim=2)
#     183     query = self._split_heads(query, self.num_heads, self.head_dim)
#     184     key = self._split_heads(key, self.num_heads, self.head_dim)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/torch/nn/modules/linear.py:116, in Linear.forward(self, input)
#     115 def forward(self, input: Tensor) -> Tensor:
# --> 116     return F.linear(input, self.weight, self.bias)
#
# KeyboardInterrupt:
